# %% [markdown]
# # Function Assignment

# %% [markdown]
# ## Q.1) Whta is the difference between a function and a method in python?

# %% [markdown]
# ### Ans :- Function - i)Function is a block of code that performs a specific task. ii) Function are used the (def) keyword. Method - i) Method is a function that is associated with object. ii) Method are typically defined and require at last one parameter (self).

# %%
## function example
def greet():
    print("Laltu")

greet()
# Out:
# Laltu

# %%
## method example
class method:
    def greet(self):
        print("Laltu")

g = method()

# %%
g.greet()
# Out:
# Laltu

# %% [markdown]
# ## Q.2) Explain the concept of function arguments and parameters in python?

# %% [markdown]
# ### Ans :- Function arguments are values that you provide to a function when you call it. These arguments can be used by the function to perform specific tasks. Parameters - Parameters are variables listed in a functions definition.

# %%
### funnction argument and parameter example
def greet(name):### name is a parameter
    print(f"Hello, {name}")

greet("Laltu")### Laltu is the argument
# Out:
# Hello, Laltu

# %% [markdown]
# ## Q.3) What are the different ways to define and call a function in python?

# %% [markdown]
# ### Ans:- The define function way to four type i) Standard Function ii)Lambda Function iii)Nested Function iv)Built in Function and Calling Functions way to five type i)Calling Standard Functions ii) Methods on Objects iii) Functions with Arguments iv)Calling Lambda Functions v)Recursively Calling Functions

# %% [markdown]
# ## Q.4) What is the purpose of the 'return' statement in a python function?

# %% [markdown]
# ### Ans :- The returns a value from the function to the caller.

# %%
def greet(self):
    return self**2

greet(5)
# Out:
# 25

# %% [markdown]
# ## Q.5) What are iterators in python and how do they differ from iterables?

# %% [markdown]
# ### Ans :- Iterator - The object to iterat over the elements one by one and used "next()" to get items.     Iterable -  The object with elements can loop through and used in loops like "for".

# %%
my_list = [1,2,3,4]
for item in my_list:
    print(item)
# Out:
# 1
# 2
# 3
# 4

# %%
list1=iter(my_list)

# %%
next(list1)
# Out:
# 1

# %%
next(list1)
# Out:
# 2

# %%
next(list1)
# Out:
# 3

# %% [markdown]
# ## Q.6) Explain the concept of generators in python and how they are defind.

# %% [markdown]
# ### Ans :- Generator is a function that produces a sequence of values lazily one at a time and generator use yield keyword to produce values.

# %%
def tools_generator():
    yield "Python"
    yield "Excel"
    yield "SQL"
for tool in tools_generator():
    print(f"Use: {tool}")
# Out:
# Use: Python
# Use: Excel
# Use: SQL

# %% [markdown]
# ## Q.7) What are the advantages of using generators over regular functions?

# %% [markdown]
# ### Ans :- Advantage of using generators over regular functions memory efficiency and more useful large data streams

# %% [markdown]
# ## Q.8) What is a lambda function in python and when is it typically used?

# %% [markdown]
# ### Ans :- Lambda  function in python is a small anonymous function defined using the "lambda" keyword.

# %%
list1 = lambda x: (x**2)
result = list1(12)
print(result)
# Out:
# 144

# %% [markdown]
# ## Q.9) Explain the purpose and usage of the 'map()' function in python.

# %% [markdown]
# ### Ans :- The map function in python is a built in function that applies a given function to all the items in an iterable and returns an iterable map object of the results.

# %%
number = [1,2,3,4,5]
squared_number = list(map(lambda x: x**2, number))
print(squared_number)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# ## Q.10) What is the difference between 'map()', 'reduce()', and 'filter()' functions in python?

# %% [markdown]
# ### Ans :- Map - Transforms each item in iterable by applying a function to it. Reduce - All items in an iterable into a single result using a cummulative function. Filter - Filter items in an iterable based on a condition.

# %% [markdown]
# ## Q.11)  Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given list:[47,11,42,13];

# %% [markdown]
# ### Ans :- doc/pdf attach

# %% [markdown]
# # Practical Questions :-

# %% [markdown]
# ## Q.1) Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.

# %%
def sum_of_even_numbers(numbers):
    return sum(num for num in numbers if num % 2 == 0)

# Example usage:
my_list = [1, 2, 3, 4, 5, 6]
result = sum_of_even_numbers(my_list)
print(f"The sum of even numbers is: {result}")
# Out:
# The sum of even numbers is: 12

# %% [markdown]
# ## Q.2) Create a Python function that accepts a string and returns the reverse of that string.

# %%
def reverse_string(l):
    return l[::-1]

# %%
## example
original_string = "Laltu Kaibartta"
reversed_string = reverse_string(original_string)
print(f"Original String: {original_string}")
print(f"Reversed String: {reversed_string}")
# Out:
# Original String: Laltu Kaibartta
# Reversed String: attrabiaK utlaL

# %% [markdown]
# ## Q.3) Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.

# %%
def square_number(numbers):
    return [num ** 2 for num in numbers]

# %%
## Example
my_list1 = [1,2,3,4,5]
squared_list = square_number(my_list1)
print(f"Original List: {my_list1}")
print(f"Squared List: {squared_list}")
# Out:
# Original List: [1, 2, 3, 4, 5]
# Squared List: [1, 4, 9, 16, 25]

# %% [markdown]
# ## Q.4) Write a Python function that checks if a given number is prime or not from 1 to 200.

# %%
def is_prime(number):
    if number <2:
        return False
    for i in range(2, int(number ** 0.5) + 1):
        if number % i == 0:
            return False
    return True

# %%
### Example
for num in range(1, 201):
    if is_prime(num):
        print(f"{num} is a prime number.")
# Out:
# 2 is a prime number.
# 3 is a prime number.
# 5 is a prime number.
# 7 is a prime number.
# 11 is a prime number.
# 13 is a prime number.
# 17 is a prime number.
# 19 is a prime number.
# 23 is a prime number.
# 29 is a prime number.
# 31 is a prime number.
# 37 is a prime number.
# 41 is a prime number.
# 43 is a prime number.
# 47 is a prime number.
# 53 is a prime number.
# 59 is a prime number.
# 61 is a prime number.
# 67 is a prime number.
# 71 is a prime number.
# 73 is a prime number.
# 79 is a prime number.
# 83 is a prime number.
# 89 is a prime number.
# 97 is a prime number.
# 101 is a prime number.
# 103 is a prime number.
# 107 is a prime number.
# 109 is a prime number.
# 113 is a prime number.
# 127 is a prime number.
# 131 is a prime number.
# 137 is a prime number.
# 139 is a prime number.
# 149 is a prime number.
# 151 is a prime number.
# 157 is a prime number.
# 163 is a prime number.
# 167 is a prime number.
# 173 is a prime number.
# 179 is a prime number.
# ...

# %% [markdown]
# ## Q.5) Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.

# %%
class Fibonacci:
    def __into__(self, num_terms):
        self.num_terms = num_terms
        self.current_term = 0
        self.a, self.b= 0, 1
    def __iter__(self):
        return self
    def __next__(self):
        if self.current_term >= self.num_terms:
            raise StopIteration
        if self.current_term == 0:
            self.current_term += 1
            return self.a
        elif self.current_term ==1:
            self.current_term += 1
            return self.b
        else:
            self.current_term += 1
            self.a, self.b = self.b, self.a + self.b
            return self.a

# %%
### Example
num_terms = 10
fib_iterator = FibonacciIterator(num_terms)
print("Fibonacci Sequence:")
for num in fib_iterator:
    print(num)
# Out:
# Fibonacci Sequence:
# 0
# 1
# 1
# 1
# 2
# 3
# 5
# 8
# 13
# 21

# %% [markdown]
# ## Q.6) Write a generator function in Python that yields the powers of 2 up to a given exponent.

# %%
def powers_of_two(number):
    for exponent in range(number + 1):
        yield 2 ** exponent

# %%
## Example
print("Power of 2:")
for power in powers_of_two(5):
    print(power)
# Out:
# Power of 2:
# 1
# 2
# 4
# 8
# 16
# 32

# %% [markdown]
# ## Q.7) Implement a generator function that reads a file line by line and yields each line as a string.

# %%
def read_file_line_by_line(file_path):
    try:
        with open(file_path, 'r') as file:
            for line in file:
                yield line.strip()
    except FileNotFoundError:
        print(f"The file at {file_path} does not exist.")
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
##Example
file_path = "pdf.txt"
for line in read_file_line_by_line(file_path):
    print(line)
# Out:
# The file at pdf.txt does not exist.

# %% [markdown]
# ## Q.8) Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.

# %%
tuple_list = [(1,3), (2,1), (3,5), (4,2)]
sorted_list = sorted(tuple_list, key=lambda x: x[1])

print(f"Original List: {tuple_list}")
print(f"Sorted List: {sorted_list}")
# Out:
# Original List: [(1, 3), (2, 1), (3, 5), (4, 2)]
# Sorted List: [(2, 1), (4, 2), (1, 3), (3, 5)]

# %% [markdown]
# ## Q.9) Write a Python program that uses 'map()' to convert a list of temperatures from Celsius to Fahrenheit.

# %%
celsius = [0, 20, 37, 50]
fahrenheit = list(map(lambda c:(9/5)*c + 32, celsius))

# %%
print(f"Celsius Temperatures: {celsius}")
print(f"Fahrenheit Temperatures: {fahrenheit}")
# Out:
# Celsius Temperatures: [0, 20, 37, 50]
# Fahrenheit Temperatures: [32.0, 68.0, 98.60000000000001, 122.0]

# %% [markdown]
# ## Q.10) Create a Python program that uses 'filtter()' to remove all the vowels from a given string.

# %%
def remove_vowels(s):
    vowels = {'a', 'e', 'i', 'o', 'u', 'A', 'E', 'I', 'O', 'U'}
    return ''.join(filter(lambda char: char not in vowels, s))

string = "Hello Pwskills! You are great"
result = remove_vowels(string)
print(f"Original String: {string}")
print(f"String without Vowels: {result}")
# Out:
# Original String: Hello Pwskills! You are great
# String without Vowels: Hll Pwsklls! Y r grt

# %% [markdown]
# ## Q.11) Imagine an accounting routine used in a book shop.It works on a list with sublists, Which look like this.

# %%
orders = [[34587, "Learning Python, Mark Lutz", 4, 40.95],
          [98762, "Programming Python, Mark Lutz", 5, 56.80],
          [77226, "Head First Python, Paul Barry", 3, 32.95],
          [88112, "Einfuhrung in Python3, Bernd Klein", 3, 24.99]]
def process_orders(order_list):
    return [
        (order[0], round(order[2] * order[3] + (10 if order[2] * order[3] < 100 else 0), 2))for order in order_list]

result = process_orders(orders)

print("Processed Orders:")
for order in result:
    print(order)
# Out:
# Processed Orders:
# (34587, 163.8)
# (98762, 284.0)
# (77226, 108.85)
# (88112, 84.97)
